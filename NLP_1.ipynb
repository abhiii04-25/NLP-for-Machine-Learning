# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("train.txt",sep=';',header=None,names=["text","emotions"])

# %%
df.loc[1]['text']
# Out:
# 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake'

# %%
df.isnull().sum()
# Out:
# text        0
# emotions    0
# dtype: int64

# %% [markdown]
# ## Converting emotions into Numbers

# %%
unique_emotions=df["emotions"].unique()
emotion_numbers={}
i=0
for emo in unique_emotions:
    emotion_numbers[emo]=i
    i+=1

df['emotions']=df['emotions'].map(emotion_numbers)

# %%
df.head()
# Out:
#                                                 text  emotions
# 0                            i didnt feel humiliated         0
# 1  i can go from feeling so hopeless to so damned...         0
# 2   im grabbing a minute to post i feel greedy wrong         1
# 3  i am ever feeling nostalgic about the fireplac...         2
# 4                               i am feeling grouchy         1

# %%
df.loc[1]['text']
# Out:
# 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake'

# %% [markdown]
# ## Text Cleaning
# ### 1. Converting to Lowercase

# %%
df['text']=df['text'].apply(lambda x:x.lower())

# %%
df.loc[1]['text']
# Out:
# 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake'

# %% [markdown]
# ### 2.Remove Punctuation

# %%
import string

def remove_punc(txt):
  return txt.translate(str.maketrans('','',string.punctuation))

# %%
df['text']=df['text'].apply(remove_punc)

# %% [markdown]
# ### Remove Numbers

# %%
def remove_number(txt):
    new = ""
    for i in txt:
        if not i.isdigit():
            new = new + i
    return new

df['text']=df['text'].apply(remove_number)

# %% [markdown]
# ### Remove Emojis and Special Character

# %%
def remove_emojis(txt):
    new = ""
    for i in txt:
        if i.isascii():
            new += i
    return new

df['text']=df['text'].apply(remove_emojis)

# %%
df.loc[1]['text']
# Out:
# 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake'

# %% [markdown]
# ### Remove Stopwords

# %%
import nltk

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Abhishek\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Abhishek\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
stop_words=set(stopwords.words('english'))

# %%
len(stop_words)
# Out:
# 198

# %%
df.loc[1]['text']
# Out:
# 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake'

# %%
def remove(txt):
    words = txt.split()
    cleaned = []
    for i in words:
        if i not in stop_words:
            cleaned.append(i)

    print("Cleaned:", cleaned)

    return ' '.join(cleaned)

# %%
df['text']=df['text'].apply(remove)
# Out:
# Cleaned: ['didnt', 'feel', 'humiliated']
# Cleaned: ['go', 'feeling', 'hopeless', 'damned', 'hopeful', 'around', 'someone', 'cares', 'awake']
# Cleaned: ['im', 'grabbing', 'minute', 'post', 'feel', 'greedy', 'wrong']
# Cleaned: ['ever', 'feeling', 'nostalgic', 'fireplace', 'know', 'still', 'property']
# Cleaned: ['feeling', 'grouchy']
# Cleaned: ['ive', 'feeling', 'little', 'burdened', 'lately', 'wasnt', 'sure']
# Cleaned: ['ive', 'taking', 'milligrams', 'times', 'recommended', 'amount', 'ive', 'fallen', 'asleep', 'lot', 'faster', 'also', 'feel', 'like', 'funny']
# Cleaned: ['feel', 'confused', 'life', 'teenager', 'jaded', 'year', 'old', 'man']
# Cleaned: ['petronas', 'years', 'feel', 'petronas', 'performed', 'well', 'made', 'huge', 'profit']
# Cleaned: ['feel', 'romantic']
# Cleaned: ['feel', 'like', 'make', 'suffering', 'seeing', 'mean', 'something']
# Cleaned: ['feel', 'running', 'divine', 'experience', 'expect', 'type', 'spiritual', 'encounter']
# Cleaned: ['think', 'easiest', 'time', 'year', 'feel', 'dissatisfied']
# Cleaned: ['feel', 'low', 'energy', 'thirsty']
# Cleaned: ['immense', 'sympathy', 'general', 'point', 'possible', 'proto', 'writer', 'trying', 'find', 'time', 'write', 'corners', 'life', 'sign', 'agent', 'let', 'alone', 'publishing', 'contract', 'feels', 'little', 'precious']
# Cleaned: ['feel', 'reassured', 'anxiety', 'side']
# Cleaned: ['didnt', 'really', 'feel', 'embarrassed']
# Cleaned: ['feel', 'pretty', 'pathetic', 'time']
# Cleaned: ['started', 'feeling', 'sentimental', 'dolls', 'child', 'began', 'collection', 'vintage', 'barbie', 'dolls', 'sixties']
# Cleaned: ['feel', 'compromised', 'skeptical', 'value', 'every', 'unit', 'work', 'put']
# Cleaned: ['feel', 'irritated', 'rejected', 'without', 'anyone', 'anything', 'saying', 'anything']
# Cleaned: ['feeling', 'completely', 'overwhelmed', 'two', 'strategies', 'help', 'feel', 'grounded', 'pour', 'heart', 'journal', 'form', 'letter', 'god', 'end', 'list', 'five', 'things', 'grateful']
# Cleaned: ['feeling', 'amused', 'delighted']
# Cleaned: ['able', 'help', 'chai', 'lifeline', 'support', 'encouragement', 'great', 'feeling', 'glad', 'able', 'help']
# Cleaned: ['already', 'feel', 'like', 'fucked', 'though', 'dont', 'usually', 'eat', 'morning']
# Cleaned: ['still', 'love', 'wish', 'best', 'longer', 'tolerate', 'effect', 'bm', 'lives', 'fact', 'turned', 'bitter', 'angry', 'person', 'always', 'particularly', 'kind', 'people', 'around', 'feeling', 'stressed']
# Cleaned: ['feel', 'inhibited', 'someone', 'elses', 'kitchen', 'like', 'im', 'painting', 'someone', 'elses', 'picture']
# Cleaned: ['become', 'overwhelmed', 'feel', 'defeated']
# Cleaned: ['feel', 'kinda', 'appalled', 'feels', 'like', 'needs', 'explain', 'wide', 'lenghth', 'body', 'measures', 'etc', 'pp']
# Cleaned: ['feel', 'superior', 'dead', 'chicken', 'grieving', 'child']
# Cleaned: ['get', 'giddy', 'feeling', 'elegant', 'perfectly', 'fitted', 'pencil', 'skirt']
# Cleaned: ['remember', 'feeling', 'acutely', 'distressed', 'days']
# Cleaned: ['seen', 'heard', 'read', 'past', 'couple', 'days', 'left', 'feeling', 'impressed', 'companies']
# Cleaned: ['climbed', 'hill', 'feeling', 'frustrated', 'id', 'pretty', 'much', 'paced', 'entirely', 'wrong', 'course', 'factor', 'never', 'ever', 'hampered', 'made', 'dent', 'day']
# Cleaned: ['imagine', 'real', 'life', 'scenario', 'would', 'emotionally', 'connected', 'enough', 'someone', 'feel', 'totally', 'accepted', 'safe', 'morally', 'acceptable', 'close', 'prolonged', 'physical', 'contact', 'sex', 'expected', 'subsequently']
# Cleaned: ['sure', 'would', 'make', 'feel', 'content', 'anything']
# Cleaned: ['feeling', 'need', 'creative']
# Cleaned: ['however', 'want', 'know', 'something', 'someone', 'causing', 'feel', 'less', 'splendid', 'self', 'step', 'away']
# Cleaned: ['feel', 'bit', 'rude', 'writing', 'elderly', 'gentleman', 'ask', 'gifts', 'feel', 'bit', 'greedy', 'christmas', 'mild', 'greed']
# Cleaned: ['need', 'need', 'someone', 'need', 'protected', 'feel', 'safe', 'small', 'find', 'season', 'words']
# Cleaned: ['plan', 'share', 'everyday', 'life', 'stories', 'traveling', 'adventures', 'inspirations', 'handmade', 'creations', 'hope', 'also', 'feel', 'inspired']
# Cleaned: ['already', 'christmas', 'trees', 'got', 'two', 'feeling', 'festive', 'sure', 'spurring', 'get', 'started', 'book']
# Cleaned: ['ive', 'worn', 'little', 'concealer', 'days', 'im', 'feeling', 'brave', 'dont', 'want', 'pale', 'perfect']
# Cleaned: ['feel', 'strongly', 'passionate', 'jerk', 'decides', 'poke', 'make', 'fun', 'us']
# Cleaned: ['feeling', 'discouraged', 'already', 'robbing', 'peter', 'pay', 'paul', 'get', 'cow', 'year', 'cant', 'afford', 'get', 'cow', 'way']
# Cleaned: ['feeling', 'listless', 'need', 'new', 'things', 'something', 'different']
# Cleaned: ['lost', 'special', 'mind', 'worry', 'still', 'sane', 'wanted', 'feel', 'felt', 'reading', 'book', 'know', 'many', 'times', 'said', 'sam', 'special', 'guarantee', 'many', 'times', 'used', 'paragraph', 'tell', 'special']
# Cleaned: ['let', 'go', 'sad', 'feeling', 'want', 'accepted', 'first', 'home', 'mine']
# Cleaned: ['boat', 'trip', 'denmark']
# Cleaned: ['stopped', 'feeling', 'cold', 'began', 'feeling', 'hot']
# Cleaned: ['need', 'feel', 'dough', 'make', 'sure', 'perfect']
# Cleaned: ['found', 'feeling', 'little', 'discouraged', 'morning']
# Cleaned: ['feel', 'selfish', 'spoiled']
# Cleaned: ['stymied', 'little', 'bit', 'wrote', 'feeling', 'unsure', 'might', 'go', 'somewhere', 'story', 'unintended']
# Cleaned: ['bag', 'qaf', 'look', 'cryin', 'jacynthe', 'lookin', 'good', 'feelin', 'gorgeous', 'rupaul', 'skins', 'scissor', 'sisters', 'valentine', 'sun', 'fed', 'kayle', 'daddy', 'gerling', 'awake', 'unkind', 'u']
# Cleaned: ['feel', 'know', 'basically', 'like', 'fake', 'realm', 'science', 'fiction']
# Cleaned: ['hate', 'living', 'dads', 'roof', 'gives', 'excuse', 'asshole', 'hes', 'providing', 'live', 'think', 'feels', 'needs', 'make', 'feel', 'unwelcome', 'possible', 'ill', 'leave']
# Cleaned: ['keep', 'feeling', 'pleasantly', 'surprised', 'supportiveness', 'also', 'ease', 'new', 'situations']
# Cleaned: ['feeling', 'anymore', 'vigorous', 'sexual', 'activity', 'coming', 'yes', 'misspelt', 'cumming', 'days', 'parts', 'begin', 'fall']
# Cleaned: ['feel', 'mom', 'graceful', 'warm', 'loving', 'smile', 'rob', 'time', 'nurture', 'heal']
# Cleaned: ['feel', 'talk', 'brother', 'law', 'extremely', 'popular', 'one', 'think', 'stiff']
# Cleaned: ['ate', 'could', 'feel', 'gentle', 'tingle', 'throughout', 'almost', 'feeling', 'healing', 'taking', 'place', 'cellular', 'level']
# Cleaned: ['feel', 'like', 'pressured', 'young', 'beautiful', 'thin', 'depending', 'trend', 'girls', 'rejuvenated', 'butt', 'implants']
# Cleaned: ['began', 'several', 'times', 'week', 'feeling', 'tortured', 'hallucinations', 'moving', 'people', 'figures', 'sounds', 'vibrations']
# Cleaned: ['nearly', 'finished', 'week', 'detox', 'feel', 'amazing']
# Cleaned: ['feel', 'selfish', 'read', 'back', 'former', 'posts', 'never', 'asked', 'prayers', 'others', 'never', 'considered', 'may', 'others', 'deserve', 'prayers', 'answered']
# Cleaned: ['know', 'pain', 'parents', 'feel', 'enraged', 'child', 'becomes', 'violent']
# Cleaned: ['roller', 'coaster', 'emotions', 'supposed', 'feelings', 'something', 'unpleasant', 'coming']
# Cleaned: ['suppose', 'truth', 'needs', 'shared', 'havent', 'feeling', 'faithful', 'lately', 'ive', 'dwelled', 'doubt', 'uncertainty', 'faith']
# Cleaned: ['feeling', 'brave', 'bought', 'clearly', 'makeup']
# Cleaned: ['feeling', 'miserable', 'c', 'also', 'proudest', 'mum', 'earth']
# Cleaned: ['figure', 'family', 'loves', 'us', 'matter', 'around', 'anyone', 'else', 'feel', 'embarrassed', 'michelle', 'goes', 'ballistic']
# Cleaned: ['necessarily', 'think', 'f', 'bombs', 'sex', 'necessary', 'stories', 'feel', 'reassured', 'see', 'print', 'journals']
# Cleaned: ['feel', 'ovaries', 'aching', 'talking', 'like', 'put']
# Cleaned: ['feel', 'like', 'much', 'chris', 'mostly', 'took', 'many', 'pictures', 'unimportant', 'stuff']
# Cleaned: ['im', 'tired', 'book', 'ready', 'finding', 'given', 'unsuitable', 'images', 'feeling', 'blamed', 'result', 'sit', 'well']
# Cleaned: ['successfully', 'manage', 'stretch', 'mxm', 'canvas', 'feel', 'achievement', 'worthwhile', 'usage', 'money', 'time', 'use', 'canvas', 'future', 'briefs']
# Cleaned: ['think', 'feelings', 'one', 'nay', 'important', 'things']
# Cleaned: ['feel', 'completely', 'honored', 'influence', 'young', 'talented', 'fully', 'alive', 'beautiful', 'girl', 'woman']
# Cleaned: ['feel', 'angered', 'firey']
# Cleaned: ['feel', 'like', 'miserable', 'piece', 'garbage']
# Cleaned: ['feel', 'like', 'need', 'make', 'list', 'leanne', 'would', 'appalled', 'thought', 'dont', 'miss', 'anything']
# Cleaned: ['drove', 'dannika', 'school', 'feeling', 'little', 'bit', 'rushed', 'greeted', 'turned', 'corner']
# Cleaned: ['remember', 'feeling', 'hellip', 'furious', 'shooter']
# Cleaned: ['feel', 'happy', 'excited', 'since', 'learned', 'many', 'things']
# Cleaned: ['feel', 'shows', 'around', 'show', 'horses', 'people', 'trusting', 'relaxed', 'show', 'horses', 'safe', 'quiet', 'handled', 'frequently']
# Cleaned: ['couple', 'things', 'left', 'make', 'start', 'december', 'done', 'feeling', 'smug']
# Cleaned: ['think', 'u', 'could', 'make', 'feel', 'realize', 'everything', 'ok']
# Cleaned: ['feel', 'worthless', 'times', 'struggling', 'finding', 'work']
# Cleaned: ['able', 'lay', 'bed', 'dark', 'feel', 'terrified', 'least']
# Cleaned: ['ready', 'meet', 'mom', 'airport', 'feel', 'ever', 'supportive', 'arms', 'around']
# Cleaned: ['im', 'feeling', 'bitter', 'today', 'mood', 'strange', 'entire', 'day', 'guess']
# Cleaned: ['mums', 'brother', 'passed', 'away', 'involved', 'car', 'accident', 'bringing', 'present', 'passed', 'form', 'five', 'exams', 'flying', 'colours']
# Cleaned: ['letting', 'go', 'animosity', 'towards', 'anyone', 'feel', 'wronged']
# Cleaned: ['talk', 'dogs', 'feel', 'cannot', 'understand', 'words', 'read', 'emotions', 'know', 'supportive', 'decided', 'go', 'home']
# Cleaned: ['feel', 'like', 'throwing', 'away', 'shitty', 'piece', 'shit', 'paper']
# Cleaned: ['im', 'starting', 'feel', 'wryly', 'amused', 'banal', 'comedy', 'errors', 'life', 'turning']
# Cleaned: ['find', 'every', 'body', 'beautiful', 'want', 'people', 'feel', 'vital', 'bodies']
# Cleaned: ['hear', 'owners', 'feel', 'victimized', 'associations', 'associations', 'attorneys', 'property', 'manager']
# Cleaned: ['say', 'goodbye', 'fam', 'theyre', 'sad', 'crying', 'feel', 'like', 'heartless', 'bitch', 'hey', 'im', 'pretty', 'excited', 'flying', 'first', 'time', 'know', 'also', 'spend', 'year', 'another', 'country']
# Cleaned: ['wont', 'let', 'child', 'cry', 'feel', 'loving', 'lily', 'little', 'going', 'opportunities', 'lasted', 'short', 'months']
# Cleaned: ['alba', 'feel', 'good', 'im', 'fitting']
# Cleaned: ['feel', 'excited', 'im', 'feel', 'like', 'ton', 'catching']
# Cleaned: ['also', 'know', 'good', 'feels', 'look', 'back', 'see', 'honored', 'word', 'helps', 'start']
# Cleaned: ['mean', 'really', 'really', 'hard', 'works', 'obtain', 'high', 'technical', 'skill', 'wushu', 'feel', 'kinda', 'ashamed', 'somehow', 'motivated', 'saw', 'kids', 'wushu', 'performances', 'whole', 'heartedly', 'despite', 'tiredness']
# Cleaned: ['feel', 'like', 'things', 'getting', 'little', 'overwhelming', 'spritz', 'toner', 'really', 'helps', 'calm', 'soothe']
# Cleaned: ['hope', 'realize', 'little', 'effort', 'required', 'make', 'person', 'feel', 'better', 'situation', 'whether', 'family', 'member', 'college', 'high', 'school', 'friend', 'neighbor', 'street', 'even', 'complete', 'stranger']
# Cleaned: ['feeling', 'festive', 'today', 'even', 'going', 'put', 'tree', 'soon', 'finished', 'catching', 'week', 'goings', 'ons', 'coronation', 'street']
# Cleaned: ['finding', 'ill', 'seriously']
# Cleaned: ['alright', 'class', 'combination', 'feeling', 'unsuccessful', 'man', 'handled', 'stress', 'late', 'horrible', 'week', 'resulted', 'almost', 'crying', 'finished', 'grappling']
# Cleaned: ['feel', 'rarely', 'advances', 'worthwhile', 'cause', 'always', 'stick', 'rule', 'posting', 'anything', 'online', 'wouldnt', 'prepared', 'say', 'somebodys', 'face']
# Cleaned: ['feeling', 'useful']
# Cleaned: ['feel', 'like', 'pains', 'cannot', 'imagine', 'becoming', 'passionate', 'group', 'idea', 'causing', 'pain']
# Cleaned: ['feel', 'ugly', 'inclined', 'wear', 'ratty', 'jeans', 'sweatshirt', 'beautiful', 'dress', 'though', 'might', 'still', 'wear', 'pair', 'heels', 'around', 'house', 'boost', 'self', 'esteem', 'ever', 'slightly', 'definitely', 'bother', 'buy', 'new', 'pair']
# Cleaned: ['im', 'feeling', 'homesick', 'yet', 'im', 'feeling', 'alright']
# Cleaned: ['dance', 'feel', 'pretty']
# Cleaned: ['workout', 'every', 'morning', 'feel', 'fabulous']
# Cleaned: ['feel', 'eyes', 'touch', 'words', 'eyes', 'know', 'assuredly', 'return', 'love', 'know', 'shall', 'vain']
# Cleaned: ['feeling', 'fabulous', 'friday', 'morning', 'started', 'get', 'awful', 'cramps', 'work']
# Cleaned: ['feel', 'honoured', 'able', 'call', 'friends', 'share', 'brotherhood']
# Cleaned: ['begun', 'feel', 'apprehensive', 'thick', 'black', 'rain', 'clouds', 'stormed', 'sky', 'town']
# Cleaned: ['stated', 'reason', 'feel', 'fearful', 'feel', 'unsafe']
# Cleaned: ['feel', 'like', 'getting', 'shaken', 'tsa', 'quite', 'yet', 'pulled', 'side', 'creative', 'croissants', 'lunch']
# Cleaned: ['get', 'groups', 'feel', 'really', 'awkward', 'overcompensate', 'talkative', 'getting', 'really', 'quiet']
# Cleaned: ['excited', 'finally', 'meet', 'companion', 'companion', 'times', 'especially', 'lonely', 'lonely', 'companion', 'never', 'disappoint', 'companion', 'put', 'arms', 'around', 'make', 'feel', 'loved']
# Cleaned: ['feel', 'pretty', 'safe', 'blog', 'img', 'src', 'http']
# Cleaned: ['feel', 'pretty', 'eager', 'get', 'done', 'fun', 'plan', 'quilting']
# Cleaned: ['feeling', 'horny', 'ask', 'lets', 'go', 'home']
# Cleaned: ['think', 'poem', 'put', 'pressure', 'feel', 'uncomfortable', 'sense', 'feeling', 'feel', 'understanding', 'understand', 'loving', 'able', 'love']
# Cleaned: ['feel', 'stranger', 'strange', 'land', 'raising', 'son', 'place', 'father', 'ancestral', 'home']
# Cleaned: ['left', 'shower', 'questioning', 'feel', 'gorgeous', 'fantastic', 'body', 'confident', 'movement', 'effortlessly', 'graceful']
# Cleaned: ['feel', 'energetic', 'bouncy', 'happy', 'go', 'gym', 'run', 'around', 'outside', 'kids', 'take', 'pram', 'long', 'walk', 'often', 'three', 'one', 'day']
# Cleaned: ['still', 'feeling', 'strong']
# Cleaned: ['burst', 'tears', 'devastating', 'release', 'feelings', 'thoughts', 'seemed', 'know', 'rich', 'also', 'go', 'space', 'without', 'dumping']
# Cleaned: ['wanted', 'get', 'pumpkin', 'spice', 'latte', 'morning', 'hot', 'last', 'thing', 'wanted', 'hot', 'coffee', 'maybe', 'feeling', 'little', 'bitter']
# Cleaned: ['suppose', 'feels', 'badly', 'bit', 'skeptical', 'pain', 'last', 'months', 'shes', 'hyperchondria', 'exaggeration', 'habit', 'past', 'though', 'never', 'openly', 'questioned']
# Cleaned: ['clench', 'corners', 'bed', 'feel', 'assured']
# Cleaned: ['also', 'feel', 'like', 'selfish', 'grateful', 'life', 'amazing', 'things']
# Cleaned: ['called', 'god', 'seen', 'god', 'book', 'figured', 'god', 'right', 'name', 'feeling', 'utterly', 'affirmed', 'accepted', 'without', 'question']
# Cleaned: ['know', 'perhaps', 'girls', 'office', 'nice', 'short', 'hair', 'perhaps', 'feeling', 'rebellious']
# Cleaned: ['feel', 'miserable', 'family', 'type', 'celebrates', 'eid']
# Cleaned: ['might', 'go', 'get', 'car', 'wash', 'feeling', 'really', 'generous', 'car', 'needs']
# Cleaned: ['still', 'feel', 'sleep', 'deprived', 'almost', 'sleeping', 'night', 'giving', 'us']
# Cleaned: ['feel', 'really', 'violent', 'right']
# Cleaned: ['bloging', 'sitting', 'feeling', 'content', 'dogs', 'amp', 'cat', 'etc', 'know', 'lucky', 'truth']
# Cleaned: ['started', 'feeling', 'funny', 'friday', 'woke', 'sick', 'dog']
# Cleaned: ['feel', 'need', 'protect', 'parents', 'witch', 'hunt', 'repressed', 'memory', 'therapy']
# Cleaned: ['feel', 'disgusted', 'even', 'associated', 'woman', 'race', 'nationality']
# Cleaned: ['laughed', 'bitterly', 'wasnt', 'feeling', 'bitter']
# Cleaned: ['know', 'feeling', 'thought', 'wished', 'could', 'us', 'us', 'knew', 'however', 'much', 'hated', 'first', 'experience', 'would', 'remember', 'forever']
# Cleaned: ['feeling', 'quite', 'mellow', 'wanted', 'soft', 'easy', 'look', 'wear', 'beginning', 'cold']
# Cleaned: ['told', 'maybe', 'need', 'time', 'think', 'ive', 'feeling', 'indecisive', 'things', 'lately']
# Cleaned: ['still', 'feel', 'genre', 'disservice', 'stories', 'resolved', 'artifically']
# Cleaned: ['always', 'know', 'feeling', 'artistic', 'write', 'name', 'artistic', 'mood', 'manitz', 'draw', 'circle', 'dot', 'bigger', 'dot', 'artistic', 'feeling', 'line', 'like', 'accent', 'mark', 'spanish', 'im', 'pissed']
# Cleaned: ['remember', 'feeling', 'really', 'terrified', 'brazil', 'bus', 'going', 'steep', 'mountain', 'hills', 'side', 'mountain', 'middle', 'big', 'storm', 'wondering', 'going', 'fall']
# Cleaned: ['could', 'feel', 'whimper', 'thought', 'unloved', 'uncared']
# Cleaned: ['im', 'certainly', 'going', 'sit', 'tell', 'whats', 'going', 'personal', 'life', 'feel', 'ever', 'curious', 'whats', 'going', 'life', 'youd', 'watch', 'show']
# Cleaned: ['im', 'sorry', 'wasnt', 'humor', 'post', 'im', 'feeling', 'funny']
# Cleaned: ['feel', 'ive', 'got', 'foot', 'door', 'fantastic', 'world', 'walking', 'running', 'trails', 'fells', 'mountains']
# Cleaned: ['say', 'whatever', 'comes', 'mind', 'tell', 'directly', 'feel', 'jealous', 'girl', 'insecure', 'love', 'person', 'trust', 'worthy', 'friend', 'sweet', 'one', 'love']
# Cleaned: ['feel', 'strange', 'coming', 'back', 'work', 'one', 'day', 'holiday']
# Cleaned: ['im', 'clearly', 'influenced', 'dash', 'happiness', 'emily', 'dickinson', 'example', 'use', 'dashes', 'instead', 'colons', 'semi', 'colons', 'enhance', 'feelings', 'rushed', 'enjambment', 'sonnet']
# Cleaned: ['fatter', 'thing', 'life', 'remain', 'control', 'whether', 'get', 'eat', 'peanut', 'butter', 'bread', 'get', 'home', 'impossible', 'day', 'first', 'world', 'looking', 'yet', 'third', 'world', 'feeling', 'hell', 'needy', 'neglected', 'little', 'girls']
# Cleaned: ['could', 'claim', 'redeem', 'genre', 'leave', 'feeling', 'entirely', 'frustrated', 'point', 'beating', 'head', 'wall', 'either']
# Cleaned: ['feel', 'sad', 'hopeless']
# Cleaned: ['im', 'getting', 'feeling', 'classes', 'little', 'intimidated', 'concept', 'lit']
# Cleaned: ['still', 'feel', 'groggy', 'get', 'routine', 'son']
# Cleaned: ['feeling', 'view', 'isnt', 'going', 'popular', 'thats', 'fine']
# Cleaned: ['want', 'hold', 'feeling', 'shocked', 'awe', 'wonder', 'forever']
# Cleaned: ['heard', 'rumour', 'st', 'year', 'exam', 'results', 'fear', 'might', 'one', 'failures']
# Cleaned: ['want', 'feel', 'valued', 'appreciated', 'know', 'people', 'love', 'arent', 'going', 'anywhere', 'even', 'nature', 'relationship', 'changes']
# Cleaned: ['know', 'days', 'feel', 'distracted']
# Cleaned: ['use', 'regularly', 'relaxing', 'music', 'always', 'feel', 'invigorated', 'afterward']
# Cleaned: ['im', 'feeling', 'distracted', 'tend', 'practice', 'eyes', 'shut', 'much', 'possible']
# Cleaned: ['feel', 'like', 'perfect', 'w', 'see', 'youtube', 'influences', 'even', 'know', 'trends']
# Cleaned: ['specifically', 'wanted', 'tango', 'feeling', 'shy', 'maks', 'quite', 'opposite', 'hard', 'get', 'far', 'enough', 'away', 'get', 'good', 'pics', 'lol']
# Cleaned: ['also', 'feel', 'weird', 'sleeping', 'bed', 'two', 'slept']
# Cleaned: ['wish', 'okay', 'thinking', 'earlier', 'today', 'heres', 'thing', 'cooped', 'amp', 'restless', 'made', 'feel', 'needy']
# Cleaned: ['ive', 'lost', 'weight', 'could', 'fit', 'tiny', 'skirt', 'ive', 'unable', 'wear', 'didnt', 'feel', 'confident']
# Cleaned: ['hope', 'feel', 'bit', 'creative', 'soon', 'miss', 'presence', 'life', 'blog']
# Cleaned: ['fan', 'current', 'president', 'conservative', 'made', 'feel', 'unwelcome']
# Cleaned: ['enclose', 'verses', 'could', 'weigh', 'much', 'thinking', 'feeling', 'curious', 'hear', 'odd', 'couple']
# Cleaned: ['begin', 'feel', 'complacent', 'life']
# Cleaned: ['feel', 'vulnerable', 'alone']
# Cleaned: ['remember', 'feeling', 'inspired', 'thinking', 'fine', 'example', 'parenting']
# Cleaned: ['feel', 'like', 'always', 'one', 'getting', 'punished', 'stupid', 'things', 'feel', 'like', 'chastised', 'behaving']
# Cleaned: ['really', 'feel', 'life', 'perfect', 'right', 'isnt', 'much', 'ask', 'hope', 'everything', 'would', 'stay']
# Cleaned: ['im', 'simply', 'feel', 'contented']
# Cleaned: ['im', 'saying', 'cut', 'everyone', 'life', 'feel', 'important', 'find', 'comfort', 'solitude', 'meditation', 'working', 'projects', 'alone']
# Cleaned: ['think', 'im', 'stupid', 'feeling', 'nervous']
# Cleaned: ['feel', 'honored']
# Cleaned: ['feeling', 'act', 'god', 'work', 'life', 'amazing', 'feeling']
# Cleaned: ['feel', 'im', 'like', 'bird', 'flying', 'air', 'carefree', 'manner']
# Cleaned: ['revise', 'replies', 'mind', 'make', 'sure', 'reply', 'sounds', 'appropriate', 'enough', 'person', 'receive', 'reply', 'feel', 'offended']
# Cleaned: ['felt', 'sad', 'friend', 'mine', 'died', 'felt', 'something', 'irrevocably', 'gone', 'away']
# Cleaned: ['died', 'would', 'alex', 'matt', 'feel', 'regretful', 'coming', 'visit']
# Cleaned: ['feel', 'educating', 'families', 'supporting', 'educationg', 'mamas', 'papas', 'key']
# Cleaned: ['im', 'sure', 'lost', 'feel', 'like', 'everyone', 'hostile', 'toward', 'hate', 'feeling']
# Cleaned: ['feel', 'like', 'boring', 'sewing', 'makes', 'since', 'easy', 'nothing', 'else', 'say', 'fabric', 'usage']
# Cleaned: ['always', 'liked', 'use', 'original', 'fragrance', 'freshen', 'lightly', 'scent', 'underwear', 'drawer', 'feel', 'gorgeously', 'glamorous', 'girly']
# Cleaned: ['feel', 'like', 'talented', 'young', 'man', 'feel', 'talented', 'work']
# Cleaned: ['feel', 'curious', 'things', 'around']
# Cleaned: ['feel', 'reason', 'apart', 'others', 'lives', 'im', 'help', 'become', 'something', 'push', 'succeed', 'successful', 'happy']
# Cleaned: ['feel', 'uncomfortable', 'guess']
# Cleaned: ['feel', 'pretty', 'mellow', 'far', 'whatever', 'healing', 'wounding', 'process', 'may', 'getting', 'underway']
# Cleaned: ['wonder', 'sometimes', 'whether', 'added', 'antagonism', 'misunderstanding', 'many', 'people', 'towards', 'us', 'feel', 'reluctant', 'wholeheartedly', 'support', 'traditional', 'armistice', 'day', 'remembrances']
# Cleaned: ['legs', 'would', 'feel', 'shitty', 'miles', 'would', 'come', 'around', 'like', 'always']
# Cleaned: ['know', 'unfair', 'reaction', 'run', 'ways', 'explain', 'feel', 'shaken', 'best', 'come', 'right']
# Cleaned: ['seriously', 'feel', 'blessed', 'support', 'home', 'amazing']
# Cleaned: ['feel', 'abused', 'maligned', 'mostly', 'tired', 'nervous', 'feeling', 'anticipating', 'danger']
# Cleaned: ['feeling', 'pretty', 'restless', 'right', 'typing']
# Cleaned: ['know', 'gosman', 'touristy', 'place', 'go', 'montauk', 'area', 'infrequent', 'visitors', 'area', 'want', 'head', 'harbor', 'feel', 'gentle', 'cawing', 'seagulls', 'lapping', 'water', 'wood', 'pilings', 'relaxing', 'breeze', 'coming', 'water']
# Cleaned: ['admit', 'hilarious', 'e', 'cards', 'seriously', 'exactly', 'feel', 'stressed', 'feel', 'moment', 'could', 'start', 'hy']
# Cleaned: ['wrote', 'last', 'year', 'feeling', 'dull', 'inarticulate', 'normal']
# Cleaned: ['id', 'kick', 'gear', 'feel', 'irritable', 'motivation', 'ever']
# Cleaned: ['feel', 'child', 'innocent', 'feelings', 'illustrating']
# Cleaned: ['satisfaction', 'feeling', 'longer', 'supporting', 'contributing', 'looter', 'driven', 'consumerism', 'made', 'walking', 'corpse', 'america', 'revered', 'younger']
# Cleaned: ['start', 'feel', 'resentful']
# Cleaned: ['spend', 'vacation', 'obligations', 'headaches', 'feeling', 'like', 'emotional', 'blackmailed', 'three', 'places']
# Cleaned: ['feel', 'herpes', 'coming', 'would', 'surprised', 'point', 'make', 'checkup', 'clinic', 'wednesday']
# Cleaned: ['feel', 'fucked', 'like', 'everyday', 'life']
# Cleaned: ['ive', 'worked', 'really', 'hard', 'year', 'try', 'make', 'child', 'class', 'feel', 'like', 'valued']
# Cleaned: ['feeling', 'disheartened', 'words', 'late']
# Cleaned: ['feel', 'like', 'bitchy', 'time', 'upon', 'retrospect', 'think', 'trying', 'shake']
# Cleaned: ['still', 'second', 'guess', 'still', 'terrible', 'time', 'making', 'definitive', 'decisions', 'certain', 'truths', 'know', 'feel', 'assured', 'truths']
# Cleaned: ['feel', 'like', 'eggs', 'benedict', 'something', 'equally', 'delicious']
# Cleaned: ['im', 'feeling', 'way', 'trusting']
# Cleaned: ['im', 'feeling', 'inspired', 'summery', 'elements', 'favorite', 'past', 'time', 'beach', 'bummin']
# Cleaned: ['feel', 'smiled', 'love', 'even', 'gorgeous']
# Cleaned: ['continue', 'define', 'discover', 'home', 'mean', 'amsterdam', 'whenever', 'feel', 'pang', 'blank', 'sickness', 'line', 'missing', 'cultural', 'mindset', 'american', 'city', 'life', 'much', 'different', 'cultural', 'mindset', 'amsterdam']
# Cleaned: ['make', 'arcade', 'simple', 'purpose', 'try', 'make', 'feel', 'absolutely', 'comfortable', 'physically', 'emotionally', 'practically', 'absolutely']
# Cleaned: ['say', 'feel', 'sympathetic']
# Cleaned: ['feeling', 'eager', 'hopped', 'tube', 'ride', 'eye', 'london']
# Cleaned: ['go', 'online', 'see', 'friend', 'talking', 'another', 'one', 'talking', 'feel', 'ignored', 'feel', 'unloved']
# Cleaned: ['monitoring', 'say', 'anything', 'ever', 'come', 'across', 'blogs', 'feel', 'offended', 'please', 'dont', 'stop']
# Cleaned: ['feel', 'like', 'weird', 'cancer', 'one', 'time']
# Cleaned: ['want', 'feel', 'safe', 'well', 'maybe', 'maybe', 'theres', 'small', 'chance', 'feel', 'joy', 'dreams', 'come', 'true']
# Cleaned: ['im', 'feeling', 'cranky']
# Cleaned: ['also', 'think', 'puzzling', 'particular', 'administrator', 'singled', 'praise', 'ability', 'get', 'students', 'read', 'feels', 'ssr', 'time', 'productive', 'use', 'class', 'time']
# Cleaned: ['tried', 'fill', 'befriending', 'people', 'knew', 'using', 'didnt', 'care', 'needed', 'feel', 'accepted', 'even', 'complete', 'loser']
# Cleaned: ['feel', 'stressed', 'always']
# Cleaned: ['remember', 'feeling', 'another', 'cramp', 'also', 'ignored']
# Cleaned: ['hope', 'feel', 'mellow', 'well', 'fed', 'well', 'slept', 'peace', 'within', 'external', 'world']
# Cleaned: ['also', 'learned', 'takes', 'lot', 'effort', 'positive', 'thinking', 'break', 'tears', 'feeling', 'exhausted', 'guilty', 'better', 'mom']
# Cleaned: ['im', 'feeling', 'awful', 'hung', 'friend', 'new', 'baby', 'day']
# Cleaned: ['feel', 'relaxed', 'fine']
# Cleaned: ['feel', 'suffering', 'really', 'feel', 'pain']
# Cleaned: ['go', 'sleep', 'feel', 'giving', 'precious', 'time', 'something', 'else', 'life']
# Cleaned: ['feel', 'like', 'neglecting', 'beloved', 'mom', 'blog']
# Cleaned: ['shalt', 'say', 'cos', 'din', 'feel', 'thing', 'wrote', 'hw', 'keen', 'xxx']
# Cleaned: ['feel', 'terrified', 'like', 'im', 'edge', 'precipice', 'staring', 'ahead']
# Cleaned: ['feel', 'totally', 'listless', 'exams', 'come', 'gone', 'whole', 'five', 'months', 'front', 'uni', 'free', 'time']
# Cleaned: ['feel', 'furious', 'right', 'life', 'advocates', 'tell', 'live', 'die', 'lobbying', 'supporting', 'politicians', 'sympathic', 'views']
# Cleaned: ['feel', 'abused', 'way']
# Cleaned: ['im', 'still', 'paying', 'attention', 'feel', 'distracted']
# Cleaned: ['started', 'third', 'block', 'feeling', 'hot', 'cold', 'tingly', 'time', 'knowing', 'still', 'five', 'hours', 'examination', 'ahead', 'idea', 'would', 'good']
# Cleaned: ['im', 'hesitant', 'make', 'suggestions', 'feel', 'outcome', 'would', 'sincere']
# Cleaned: ['feel', 'terribly', 'fond', 'majority', 'precise', 'time']
# Cleaned: ['feel', 'gaining', 'control', 'damaged', 'goods', 'aspects', 'personal', 'security']
# Cleaned: ['bombed', 'first', 'interview', 'left', 'second', 'interview', 'feeling', 'pretty', 'fan', 'freaking', 'tastic']
# Cleaned: ['think', 'kind', 'taken', 'us', 'long', 'build', 'good', 'inventory', 'sauces', 'oils', 'spices', 'non', 'perishables', 'feel', 'like', 'chance', 'making', 'something', 'delicious', 'without', 'specifically', 'go', 'buy', 'every', 'single', 'item', 'recipe']
# Cleaned: ['feel', 'advise', 'dads', 'whose', 'children', 'soon', 'become', 'teenagers', 'cool', 'pull', 'kid', 'high', 'school', 'pick', 'smelly', 'jalopy', 'plants', 'coming', 'windows']
# Cleaned: ['feel', 'victimized', 'drag', 'country', 'heads', 'sand', 'traditionalists', 'hesitate', 'call', 'conservatives', 'fear', 'offending', 'real', 'honest', 'god', 'conservatives', 'still', 'think', 'world', 'created', 'years', 'ago', 'stuff', 'like', 'skeletal', 'remains', 'kind', 'hoax']
# Cleaned: ['would', 'feel', 'lucky', 'call', 'materials', 'kits', 'site', 'mine', 'beautifully', 'curated']
# Cleaned: ['bloods', 'proved', 'reason', 'feeling', 'lethargic', 'rubbish', 'low', 'iron', 'prescribed', 'iron', 'tablets']
# Cleaned: ['mind', 'feel', 'like', 'mind', 'dangerous', 'life']
# Cleaned: ['feel', 'like', 'love', 'everyone', 'least', 'compassionate', 'toward', 'others']
# Cleaned: ['feel', 'punished', 'neglecting']
# Cleaned: ['feel', 'like', 'doesnt', 'capture', 'beauty', 'lovely', 'polish']
# Cleaned: ['feel', 'like', 'lost', 'main', 'roots', 'feel', 'less', 'secure', 'emotionally', 'financially', 'socially']
# Cleaned: ['feel', 'like', 'bite', 'bullet', 'every', 'time', 'think', 'feel', 'stressed', 'im', 'fully', 'supported', 'decisions']
# Cleaned: ['know', 'obnoxiously', 'immature', 'sounding', 'verbal', 'tics', 'voice', 'kind', 'nasal', 'always', 'come', 'across', 'like', 'sharpest', 'tool', 'shed', 'especially', 'feeling', 'awkward', 'knowing', 'knowing', 'know']
# Cleaned: ['id', 'terrible', 'nightmare', 'feeling', 'little', 'disturbed']
# Cleaned: ['didnt', 'want', 'walk', 'passed', 'case', 'customers', 'feel', 'disturbed']
# Cleaned: ['want', 'sufferers', 'able', 'find', 'hope', 'battle', 'help', 'feel', 'alone']
# Cleaned: ['feeling', 'exceptionally', 'reluctant', 'go', 'school', 'tomorrow', 'even', 'though', 'monday', 'timetable', 'pretty', 'good']
# Cleaned: ['festive', 'feels', 'delicious', 'wheeeeee', 'great', 'night']
# Cleaned: ['looking', 'forward', 'beaten', 'feeling', 'like', 'disappointment', 'husband', 'emotional', 'pain']
# Cleaned: ['im', 'sick', 'feeling', 'crappy']
# Cleaned: ['feel', 'like', 'almost', 'convinced', 'going', 'pattern']
# Cleaned: ['also', 'wear', 'im', 'wearing', 'dress', 'makes', 'feel', 'slutty', 'feels', 'like', 'antique', 'underwears', 'obviously', 'little', 'bit', 'edgy', 'maybe', 'little', 'bit', 'little', 'bit']
# Cleaned: ['feel', 'perverse', 'pride', 'self', 'control', 'managed', 'stay', 'ordered', 'reach', 'tempting', 'human', 'flesh', 'close', 'us']
# Cleaned: ['feel', 'impatient', 'easily', 'annoyed', 'outraged', 'blatant', 'defiance', 'seems', 'olivias', 'prominent', 'characteristic', 'days']
# Cleaned: ['positively', 'giddy', 'kids', 'left', 'morning', 'last', 'official', 'class', 'year', 'im', 'feeling', 'little', 'sad']
# Cleaned: ['feel', 'supportive', 'also', 'cant', 'help', 'feel', 'jealous']
# Cleaned: ['mainly', 'like', 'text', 'feel', 'like', 'much', 'clever', 'written', 'word', 'rather', 'spoken']
# Cleaned: ['seriouly', 'feel', 'respected', 'dont', 'privacy', 'ordered', 'around']
# Cleaned: ['said', 'words', 'devotee', 'feel', 'relieved', 'hear', 'title', 'deen', 'bandhu', 'fallen', 'person', 'become', 'afraid', 'title', 'uplifter', 'devotees', 'consider', 'true', 'devotee', 'hence', 'unworthy', 'benefit', 'aspect', 'personality']
# Cleaned: ['personalities', 'feel', 'pain', 'suffering']
# Cleaned: ['guess', 'would', 'feel', 'like', 'joseph', 'walt', 'trusting', 'care', 'mother', 'finances', 'six', 'months', 'died', 'times', 'want', 'defend', 'self', 'god', 'makes', 'quiet']
# Cleaned: ['warming', 'starting', 'feeling', 'little', 'lethargic']
# Cleaned: ['feel', 'excelent', 'sometimes', 'theres', 'nothing', 'especially', 'since', 'im', 'really', 'keen', 'video', 'games', 'anymore', 'watch', 'bit', 'anime', 'movies', 'theres', 'got', 'life']
# Cleaned: ['wonder', 'master', 'feeling', 'r', 'wanting', 'eager', 'please', 'master', 'could', 'much', 'enjoy', 'attentions', 'wrong', 'desire', 'return', 'affections']
# Cleaned: ['im', 'feeling', 'little', 'bit', 'positive', 'things', 'quite', 'hard', 'first', 'savings', 'eaten', 'quickly', 'costs', 'didnt', 'want', 'become', 'burden', 'boyfriend', 'weve', 'come', 'end', 'im', 'feeling', 'brighter', 'inspired', 'things', 'come']
# Cleaned: ['im', 'feeling', 'rather', 'sentimental', 'right', 'say', 'feel', 'lucky', 'maxs', 'mom']
# Cleaned: ['make', 'show', 'feel', 'isolated', 'crowd', 'ill', 'know', 'wrong', 'anti', 'social', 'feeling']
# Cleaned: ['ive', 'learned', 'turn', 'emotions', 'often', 'find', 'feeling', 'completely', 'blank', 'mother', 'crying', 'continuously', 'suicidalness']
# Cleaned: ['feel', 'loyal', 'style']
# Cleaned: ['understand', 'may', 'feel', 'youd', 'rather', 'bit', 'vulnerable', 'homeless', 'london', 'precise', 'way']
# Cleaned: ['finally', 'stop', 'feeling', 'listless', 'like', 'waste', 'space']
# Cleaned: ['know', 'im', 'feeling', 'agitated', 'side', 'effect', 'high', 'dose']
# Cleaned: ['feel', 'shift', 'positive']
# Cleaned: ['feeling', 'brave', 'enough']
# Cleaned: ['fear', 'thief']
# Cleaned: ['feel', 'clever', 'nov']
# Cleaned: ['always', 'spend', 'money', 'mean', 'feel', 'dissatisfied', 'exit', 'store']
# Cleaned: ['im', 'feeling', 'really', 'quite', 'angry']
# Cleaned: ['feel', 'kerry', 'didnt', 'supporting', 'civil', 'unions', 'gay', 'equality']
# Cleaned: ['feel', 'really', 'ashamed']
# Cleaned: ['feel', 'amazing', 'people', 'life']
# Cleaned: ['finally', 'left', 'feeling', 'judged', 'ridiculed', 'intelligent']
# Cleaned: ['starting', 'feel', 'bit', 'insulted', 'stranger']
# Cleaned: ['many', 'days', 'feel', 'hopeless', 'today', 'light', 'end', 'yellow', 'brick', 'road', 'shining', 'little', 'brighter']
# Cleaned: ['actually', 'feel', 'sorrowful']
# Cleaned: ['see', 'women', 'wearing', 'boots', 'feel', 'envious', 'want', 'curse']
# Cleaned: ['feel', 'feel', 'tell', 'together', 'apologize', 'make', 'keep', 'loving', 'bits', 'bits']
# Cleaned: ['go', 'say', 'feeling', 'impressed', 'youre', 'naomi', 'klein', 'right']
# Cleaned: ['began', 'feel', 'senses', 'dull', 'cold', 'black', 'unconsciousness', 'came']
# Cleaned: ['suspect', 'feel', 'less', 'fond', 'private']
# Cleaned: ['honoured', 'young', 'woman', 'felt', 'comfortable', 'enough', 'ask', 'kind', 'faux', 'hawk', 'thing', 'going', 'back', 'must', 'looked', 'dykey', 'enough', 'feel', 'safe', 'talking']
# Cleaned: ['wonder', 'cast', 'caveman', 'told', 'perfect', 'part', 'feel', 'insulted', 'complimented']
# Cleaned: ['feel', 'convinced', 'plus', 'many', 'diverse', 'price', 'tags', 'feel', 'sure', 'everyone', 'come', 'funds', 'plot', 'lighted', 'relatively', 'economically']
# Cleaned: ['feel', 'empty', 'baby', 'isnt']
# Cleaned: ['stopped', 'feeling', 'exhausted', 'href', 'http', 'provokingbeauty']
# Cleaned: ['im', 'feeling', 'font', 'friendly']
# Cleaned: ['hand', 'beads', 'consciously', 'breathing', 'consciously', 'working', 'feel', 'calm', 'list', 'things', 'accomplish', 'afternoon']
# Cleaned: ['always', 'feel', 'intimidated', 'people', 'especially', 'always', 'compare', 'people', 'ever', 'since', 'young']
# Cleaned: ['made', 'feel', 'rotten']
# Cleaned: ['started', 'feeling', 'hostile', 'checking', 'hemorrhoids']
# Cleaned: ['love', 'wearing', 'new', 'shoes', 'feel', 'glamourous', 'get', 'pair', 'designer', 'shoes', 'love', 'box', 'trimmings', 'come']
# Cleaned: ['know', 'largely', 'fact', 'feelings', 'romantic', 'sexual', 'successfully', 'hidden']
# Cleaned: ['love', 'feeling', 'something', 'warmly', 'hugging', 'feeling', 'precious', 'small', 'precious', 'someone', 'something']
# Cleaned: ['im', 'feeling', 'far', 'mellow', 'normal']
# Cleaned: ['became', 'dismayed', 'studied', 'people', 'wearing', 'started', 'feeling', 'like', 'though', 'outfits', 'gorgeous', 'bought', 'way']
# Cleaned: ['dont', 'want', 'wax', 'draw', 'anything', 'need', 'unibrow', 'maybe', 'get', 'rid', 'spare', 'hairs', 'creeping', 'toward', 'eyelid', 'im', 'feeling', 'brave']
# Cleaned: ['im', 'feeling', 'lucky', 'width', 'li', 'style', 'border', 'px', 'list', 'style', 'outside', 'margin', 'px', 'px']
# Cleaned: ['recall', 'high', 'school', 'feelings', 'longing', 'watched', 'olympic', 'runners', 'feel', 'st']
# Cleaned: ['woke', 'feeling', 'confident', 'watched', 'bodypump', 'dvd', 'gather', 'coaching', 'tips', 'compulsory', 'cues']
# Cleaned: ['didnt', 'say', 'strong', 'feelings', 'always', 'make', 'skeptical', 'first']
# Cleaned: ['want', 'talk', 'limited', 'time', 'phone', 'current', 'arrangment', 'feel', 'hesitant', 'bring']
# Cleaned: ['beginning', 'feel', 'theres', 'good', 'chance', 'might', 'pass']
# Cleaned: ['feel', 'like', 'little', 'control', 'help', 'sweet', 'pea', 'better', 'know', 'ahead']
# Cleaned: ['feel', 'like', 'receiving', 'end', 'violent', 'attack']
# Cleaned: ['feel', 'worthwhile', 'document', 'people', 'familiar', 'batch', 'files']
# Cleaned: ['feeling', 'especially', 'thankful', 'many', 'small', 'blessings', 'life', 'right']
# Cleaned: ['hoping', 'weatherman', 'right', 'forecast', 'stay', 'home', 'dont', 'venture', 'rain', 'tomorrow', 'feeling', 'kind', 'creative']
# Cleaned: ['feel', 'like', 'im', 'edge', 'microcosm', 'one', 'awkward', 'moment', 'missed', 'party', 'id', 'outside']
# Cleaned: ['feel', 'bit', 'funny', 'actually']
# Cleaned: ['learnt', 'nothing', 'else', 'last', 'two', 'years', 'best', 'feel', 'way', 'trusting', 'instincts']
# Cleaned: ['feeling', 'also', 'blossoming', 'eager', 'anxiety']
# Cleaned: ['feel', 'burdened', 'share']
# Cleaned: ['always', 'want', 'nemo', 'side', 'sleeping', 'without', 'feels', 'weird', 'even', 'though', 'doesnt', 'happen', 'often', 'get']
# Cleaned: ['im', 'feeling', 'outfit', 'heels', 'gorgeous']
# Cleaned: ['feel', 'confused']
# Cleaned: ['feel', 'session', 'useful', 'gave', 'tools', 'need', 'move', 'forward', 'life']
# Cleaned: ['feel', 'selfish', 'bringing', 'loneliness', 'child', 'know', 'parents', 'newtown', 'grieving', 'lost', 'babies']
# Cleaned: ['took', 'away', 'disappointed', 'feeling', 'paining', 'gave', 'heart', 'heal', 'lord', 'one', 'love', 'never', 'betrayed', 'never', 'lose', 'loyalty', 'even', 'loyal']
# Cleaned: ['feel', 'envious', 'embarrassed']
# Cleaned: ['could', 'feel', 'frantic', 'need', 'need', 'make']
# Cleaned: ['feeling', 'overwhelmed', 'responsibilities', 'teacher', 'someone', 'trusting', 'precious', 'gift', 'honor']
# Cleaned: ['feel', 'tranquil', 'right', 'great']
# Cleaned: ['feel', 'frustrated', 'new', 'music', 'new', 'lyrics', 'clearly', 'nothing']
# Cleaned: ['thought', 'going', 'talk', 'try', 'work', 'things', 'shocked', 'find', 'steve', 'decided', 'wanted', 'thing', 'broke', 'feeling', 'unloved']
# Cleaned: ['wouldnt', 'beared', 'witness', 'incredibly', 'well', 'spoken', 'bouncer', 'making', 'emo', 'kid', 'feel', 'completely', 'unwelcome']
# Cleaned: ['tend', 'stop', 'breathing', 'feeling', 'stressed']
# Cleaned: ['smoker', 'years', 'quit', 'weeks', 'ago', 'right', 'finished', 'book', 'cant', 'believe', 'free', 'feel', 'knew', 'quit', 'terrified', 'life', 'without', 'cigarettes']
# Cleaned: ['go', 'mailbox', 'talk', 'mailman', 'grocery', 'clerk', 'etc', 'matter', 'small', 'step', 'limited', 'risk', 'complete', 'total', 'willingness', 'experience', 'whatever', 'thoughts', 'feelings', 'sensations', 'emerge', 'important']
# Cleaned: ['already', 'feeling', 'frantic']
# Cleaned: ['feel', 'like', 'insecurity', 'good', 'thing', 'first', 'started', 'writing', 'pictured']
# Cleaned: ['feel', 'complimented', 'insulted']
# Cleaned: ['crave', 'fall', 'submission', 'feel', 'submissive', 'least']
# Cleaned: ['feel', 'tender', 'fine']
# Cleaned: ['feel', 'irritated', 'pissed', 'even', 'like', 'someone', 'wakes', 'moment', 'edge', 'falling', 'deep', 'slumber']
# Cleaned: ['made', 'work', 'feeling', 'little', 'groggy']
# Cleaned: ['want', 'love', 'feel', 'like', 'sort', 'hindrance', 'thats', 'keeping', 'loving']
# Cleaned: ['feel', 'fond', 'ok', 'second', 'thought', 'really', 'sensitive', 'spelled', 'everything']
# Cleaned: ['ill', 'get', 'round', 'quarter', 'im', 'feeling', 'hopeful', 'one']
# Cleaned: ['im', 'starting', 'feel', 'unwelcome', 'life', 'people', 'already', 'tell']
# Cleaned: ['feel', 'absolutely', 'fantastic', 'hope', 'baby']
# Cleaned: ['watched', 'snow', 'fall', 'accumulate', 'conifer', 'trees', 'shoveling', 'shirt', 'sleeves', 'feeling', 'vigorous']
# Cleaned: ['feel', 'bitter', 'honkerblonked', 'general']
# Cleaned: ['feeling', 'father', 'already', 'convinced']
# Cleaned: ['love', 'feel', 'passionate', 'living', 'dream', 'gotten', 'taste', 'feels', 'like', 'nothing', 'stop']
# Cleaned: ['play', 'rain', 'squeal', 'glee', 'feeling', 'mud', 'squishing', 'toes', 'enjoy', 'pretty', 'much', 'anything', 'takes', 'place', 'outdoors']
# Cleaned: ['feeling', 'humorous', 'put', 'cold', 'callers', 'hold']
# Cleaned: ['busy', 'stuffs', 'never', 'blogs', 'threads', 'make', 'feel', 'miserable']
# Cleaned: ['feel', 'energized', 'curious', 'life', 'god', 'potential', 'give', 'something', 'back', 'society', 'finding', 'someone', 'heart']
# Cleaned: ['feel', 'privileged', 'also', 'lot', 'work']
# Cleaned: ['im', 'pretty', 'happy', 'little', 'nauseated', 'side', 'feel', 'thrilled']
# Cleaned: ['close', 'eyes', 'hear', 'pitiful', 'wailing', 'sounds', 'cries', 'taste', 'salty', 'taste', 'tears', 'feel', 'anger', 'hurt', 'saturating', 'heart']
# Cleaned: ['bought', 'virtually', 'fat', 'free', 'thousand', 'islands', 'feeling', 'impressed', 'hold', 'large', 'quantities', 'substance', 'leaves', 'lettuce', 'cucumber', 'friend', 'total', 'sugar', 'becomes', 'burn', 'fat']
# Cleaned: ['im', 'sure', 'folks', 'virginia', 'florida', 'handful', 'swing', 'states', 'agree', 'feel', 'put', 'upon', 'insulted', 'constant', 'barrage']
# Cleaned: ['feel', 'like', 'im', 'putting', 'innocent', 'man', 'death', 'row']
# Cleaned: ['sure', 'else', 'help', 'feel', 'smart']
# Cleaned: ['begin', 'feel', 'every', 'waking', 'moment', 'devoted', 'work']
# Cleaned: ['feel', 'thankful', 'lessons', 'learning']
# Cleaned: ['feel', 'longing', 'sadness', 'see', 'families', 'children']
# Cleaned: ['feel', 'distinctly', 'called', 'clermont', 'focus', 'little', 'ones', 'seem', 'naughty']
# Cleaned: ['hope', 'feel', 'glad', 'gave', 'many', 'things', 'including', 'memories', 'cherish']
# Cleaned: ['feeling', 'pretty', 'worthless', 'right']
# Cleaned: ['feel', 'projects', 'clever', 'useful', 'enough', 'figured', 'would', 'start', 'sharing', 'instructables', 'wrote', 'first', 'one', 'weekend']
# Cleaned: ['continued', 'think', 'along', 'lines', 'probably', 'would', 'done', 'dishes', 'anger', 'got', 'wed', 'fight', 'feeling', 'completely', 'abused']
# Cleaned: ['didnt', 'feel', 'especially', 'nervous', 'finland', 'landed', 'paris', 'little', 'unsure', 'would', 'ahead', 'us', 'thought', 'st', 'grade', 'student', 'janne', 'suominen']
# Cleaned: ['feel', 'envious', 'kids', 'certain', 'moments']
# Cleaned: ['feeling', 'like', 'pretty', 'crappy', 'mom']
# Cleaned: ['im', 'feeling', 'pissed', 'aac', 'feeling', 'kind', 'miserable', 'frustrated', 'life', 'whole', 'week']
# Cleaned: ['im', 'scared', 'anymore', 'im', 'fine', 'feel', 'terrific', 'surgery']
# Cleaned: ['still', 'feel', 'vulnerable', 'around']
# Cleaned: ['honestly', 'sure', 'feel', 'stunned']
# Cleaned: ['feel', 'caring', 'person', 'attract', 'caring', 'people', 'life']
# Cleaned: ['im', 'left', 'feeling', 'quite', 'embarrassed', 'say', 'nothings', 'new']
# Cleaned: ['feel', 'unwelcome', 'place', 'buti', 'cant', 'decide', 'scared', 'anything', 'ok', 'situation', 'staying', 'dead', 'end', 'situation', 'afraid', 'things', 'get', 'worse']
# Cleaned: ['may', 'may', 'cried', 'thanking', 'making', 'children', 'feel', 'special', 'loved']
# Cleaned: ['really', 'want', 'go', 'buy', 'yardage', 'art', 'gallery', 'play', 'feels', 'amazing']
# Cleaned: ['feel', 'like', 'shes', 'losing', 'sense', 'self', 'adapt', 'thinks', 'loyal']
# Cleaned: ['feel', 'burdened', 'several', 'loved', 'ones', 'miss', 'big', 'kid', 'havent', 'seen', 'since', 'friday']
# Cleaned: ['feel', 'still', 'really', 'low', 'abdomen']
# Cleaned: ['feel', 'like', 'welcomed', 'tight', 'knit', 'family', 'make', 'sure', 'feel', 'alone', 'ever']
# Cleaned: ['feel', 'doubtful']
# Cleaned: ['usually', 'use', 'smaller', 'legos', 'however', 'year', 'students', 'fine', 'motor', 'delays', 'want', 'students', 'feel', 'successful']
# Cleaned: ['get', 'exercise', 'feel', 'like', 'im', 'something', 'worthwhile', 'meantime']
# Cleaned: ['feel', 'like', 'life', 'rich', 'fulfilling', 'know', 'people', 'look', 'way', 'live', 'feel', 'misplaced', 'pity']
# Cleaned: ['feel', 'blessed', 'amazed', 'yes', 'excited']
# Cleaned: ['feel', 'hesitant', 'talking']
# Cleaned: ['try', 'get', 'least', 'minutes', 'day', 'five', 'days', 'week', 'though', 'known', 'skip', 'workout', 'feeling', 'particularly', 'lethargic', 'lazy']
# Cleaned: ['feeling', 'beaten', 'sick', 'utterly', 'devoid', 'hope', 'ever', 'life', 'want']
# Cleaned: ['feel', 'hesitant', 'comment', 'want', 'add', 'pileon', 'seems', 'clear', 'involved', 'learned', 'past', 'experiences', 'interested', 'applying', 'learning', 'future', 'projects']
# Cleaned: ['feel', 'quite', 'passionate', 'communion', 'tremendous', 'importance', 'personally', 'theologically']
# Cleaned: ['im', 'feeling', 'happy', 'well']
# Cleaned: ['find', 'much', 'time', 'think', 'without', 'feeling', 'depressed', 'actually', 'able', 'write', 'imagine', 'without', 'feeling', 'trapped', 'like', 'missing', 'something', 'near', 'constant', 'feeling', 'cities']
# Cleaned: ['got', 'feeling', 'brig', 'sincere', 'strong', 'desire', 'help', 'others', 'become', 'successful', 'financially', 'also', 'building', 'strengthening', 'relationships', 'christianity']
# Cleaned: ['feel', 'like', 'ive', 'fake', 'feelings', 'lot', 'often', 'would', 'liked']
# Cleaned: ['feeling', 'energetic', 'decided', 'going', 'bike', 'rest', 'temples']
# Cleaned: ['im', 'really', 'like', 'said', 'understand', 'way', 'feel', 'toni', 'ight', 'blamed', 'excesses', 'merican', 'dream', 'seldom', 'witnessed', 'never', 'er', 'seen', 'hah', 'hah', 'hah', 'hah', 'hah']
# Cleaned: ['happpy', 'get', 'good', 'results', 'field', 'academics', 'athletics']
# Cleaned: ['dont', 'know', 'want', 'work', 'always', 'something', 'makes', 'feel', 'stressed', 'anxious', 'work', 'whatever', 'job', 'may', 'jobs', 'require', 'sort', 'rules', 'pressure']
# Cleaned: ['id', 'pop', 'chair', 'feeling', 'like', 'something', 'worthwhile']
# Cleaned: ['really', 'hoping', 'theyd', 'get', 'far', 'enough', 'ahead', 'us', 'could', 'feel', 'like', 'navigating', 'delighted', 'punching', 'second', 'control', 'headed', 'onto', 'trail', 'woods']
# Cleaned: ['feel', 'like', 'normally', 'would', 'angry', 'thats', 'actually', 'think', 'could', 'never', 'beautiful', 'size']
# Cleaned: ['wonder', 'many', 'people', 'feel', 'like', 'perspective', 'think', 'sake', 'without', 'wanting', 'turn', 'result', 'crappy', 'work']
# Cleaned: ['feel', 'indecisive', 'whether', 'feel', 'book', 'huckleberry', 'finn', 'censored']
# Cleaned: ['known', 'likes', 'kamiki', 'kun', 'laughs', 'nozomi', 'feels', 'unpleasant', 'knot', 'stomach', 'must', 'think', 'fool', 'nonchan']
# Cleaned: ['made', 'choice', 'start', 'recognizing', 'feeling', 'unloved', 'kicks', 'choose', 'keep', 'persistence', 'level', 'allowing', 'old', 'reaction', 'shut']
# Cleaned: ['feel', 'like', 'im', 'hated', 'celebrated', 'cant', 'wait', 'till', 'day', 'say', 'made']
# Cleaned: ['still', 'feel', 'funny', 'writing', 'like', 'maybe', 'call', 'spirit', 'guide', 'really', 'observant', 'cheerleader', 'something']
# Cleaned: ['would', 'rather', 'feel', 'nothing', 'feel', 'surprised', 'find', 'life', 'depressing', 'grey', 'unrewarding']
# Cleaned: ['feel', 'comfortable', 'decision']
# Cleaned: ['get', 'really', 'sweaty', 'episodes', 'stomach', 'feel', 'really', 'funny', 'like', 'free', 'falling']
# Cleaned: ['feeling', 'overwhelmed', 'lately']
# Cleaned: ['learnt', 'much', 'wonderful', 'world', 'beaubronz', 'feel', 'lovely', 'tanning', 'brand', 'fits', 'perfectly', 'latest', 'mantra', 'stolen', 'boudoir', 'lashes', 'mother', 'asma', 'docrat']
# Cleaned: ['feel', 'rebellious', 'particularly', 'like', 'watching', 'romcoms', 'get', 'feeling', 'may', 'pretty', 'good', 'writing']
# Cleaned: ['didnt', 'feel', 'welcomed', 'first', 'entered', 'morris', 'quickly', 'changed', 'left', 'feeling', 'happy']
# Cleaned: ['im', 'contemplating', 'feeling', 'skeptical']
# ...
# Cleaned: ['feel', 'sorry', 'father']
# Cleaned: ['feel', 'tremendously', 'lonely']
# Cleaned: ['im', 'really', 'feeling', 'lonely']
# Cleaned: ['like', 'slump', 'feeling', 'precious']
# Cleaned: ['try', 'stay', 'feelings', 'caring', 'meditating', 'dancing', 'sometimes', 'writing']
# Cleaned: ['feel', 'like', 'something', 'tragic', 'going', 'happen', 'people', 'wake', 'see', 'vulturous', 'sic', 'poisonous', 'gotten']
# Cleaned: ['feel', 'safe', 'accepted']
# Cleaned: ['would', 'well', 'psychiatry', 'really', 'feel', 'patients', 'super', 'perceptive', 'things', 'people', 'dont', 'pick']
# Cleaned: ['never', 'grumbled', 'feel', 'unhappy', 'help', 'even', 'exam', 'lord']
# Cleaned: ['im', 'feeling', 'nervous', 'since', 'wasnt', 'sore', 'touch', 'stretch', 'use', 'muscles', 'felt', 'assured', 'nothing', 'would', 'pass']
# Cleaned: ['ive', 'wrestling', 'feeling', 'jealous', 'envious', 'gfs', 'bf', 'since', 'hes', 'staying']
# Cleaned: ['say', 'feel', 'like', 'terrible', 'person', 'completely', 'love', 'book']
# Cleaned: ['feel', 'duty', 'help', 'needy', 'vivek', 'oberoi']
# Cleaned: ['feel', 'ashamed', 'afraid', 'let', 'people', 'come', 'see', 'messy', 'house', 'afraid', 'pulled', 'car', 'towed', 'unpaid', 'ticket', 'afraid', 'blood', 'work', 'come', 'back', 'diagnosis', 'imminent', 'death']
# Cleaned: ['guess', 'ill', 'feel', 'awkward', 'till', 'get', 'shit']
# Cleaned: ['im', 'feeling', 'productive', 'today']
# Cleaned: ['feeling', 'sort', 'heat', 'exhausted']
# Cleaned: ['feel', 'nothing', 'long', 'stretches', 'time', 'im', 'convinced', 'nothing', 'worked']
# Cleaned: ['sick', 'feeling', 'lethargic', 'time']
# Cleaned: ['could', 'vocalize', 'feelings', 'would', 'put', 'sarcastic', 'great']
# Cleaned: ['busy', 'analysing', 'wrong', 'end', 'feeling', 'bitter', 'things', 'makes', 'happy']
# Cleaned: ['feel', 'absence', 'herbs', 'especially', 'craving', 'delicious', 'homemade', 'soup']
# Cleaned: ['went', 'sleep', 'friday', 'feeling', 'relieved', 'none', 'family', 'caught', 'tornadoes', 'broken', 'arrow', 'later', 'night']
# Cleaned: ['feel', 'getting', 'frantic', 'close', 'pull', 'turn', 'around', 'surprised', 'move', 'easily']
# Cleaned: ['really', 'feel', 'way', 'single', 'day', 'gone', 'ive', 'felt', 'insecure', 'jerome']
# Cleaned: ['feel', 'irritable', 'supersensitive']
# Cleaned: ['feeling', 'much', 'like', 'experiencing', 'strange', 'head', 'neck', 'twinges']
# Cleaned: ['feel', 'virtuous', 'expressing', 'fears', 'contamination']
# Cleaned: ['dont', 'want', 'make', 'someone', 'need', 'feel', 'helpless', 'without']
# Cleaned: ['tried', 'make', 'cheerful', 'comment', 'fitting', 'feel', 'really', 'unwelcome']
# Cleaned: ['imagine', 'stay', 'forever', 'feel', 'thrilled', 'copy', 'dip', 'back', 'whenever', 'wish']
# Cleaned: ['spent', 'lot', 'time', 'feeling', 'bit', 'stunned', 'thought', 'awesome']
# Cleaned: ['would', 'give', 'everything', 'know', 'share', 'pain', 'feel', 'aching', 'caused', 'parting']
# Cleaned: ['stand', 'looking', 'tower', 'feeling', 'waves', 'nostalgia', 'longing']
# Cleaned: ['wanted', 'loves', 'feel', 'like', 'cares', 'enough', 'even', 'doesnt', 'care', 'wedding', 'supportive', 'throw', 'face']
# Cleaned: ['look', 'see', 'stares', 'feel', 'also', 'know', 'sympathetic', 'glances', 'american', 'friends', 'give']
# Cleaned: ['sitting', 'corner', 'stewing', 'muck', 'feeling', 'hated', 'alone', 'unworthy', 'violated']
# Cleaned: ['ive', 'told', 'parents', 'honestly', 'feel', 'course', 'im', 'glad', 'theyre', 'gonna', 'back', 'let', 'decide', 'want', 'next', 'life']
# Cleaned: ['feel', 'enraged', 'life', 'taken', 'advantage', 'yet']
# Cleaned: ['feel', 'quite', 'fearful', 'future', 'times', 'wonder', 'happened', 'even', 'something', 'cause', 'abbigail', 'apraxia']
# Cleaned: ['get', 'slightly', 'warm', 'feeling', 'coming', 'strange', 'sense', 'completeness', 'like', 'feeling', 'get', 'right', 'afterwards', 'except', 'coupled', 'thoughts', 'one', 'night', 'stand', 'sobered', 'left', 'morning']
# Cleaned: ['still', 'feel', 'terrible', 'right', 'happened', 'monday', 'night', 'needed', 'time', 'recover', 'sharing', 'sleeping', 'since', 'happened']
# Cleaned: ['mean', 'feels', 'feels', 'everyfuckingthing', 'fault', 'fucking', 'makes', 'irritated', 'im', 'neither', 'passive', 'enough', 'tolerate', 'fault']
# Cleaned: ['like', 'cause', 'take', 'one', 'muscle', 'pains', 'want', 'feel', 'groggy']
# Cleaned: ['cant', 'tell', 'moments', 'shock', 'im', 'feeling', 'im', 'jaded', 'lovecraft', 'actually', 'missed', 'note', 'use', 'musical', 'analogy']
# Cleaned: ['feel', 'inspired']
# Cleaned: ['need', 'little', 'pick', 'sue', 'sparkly', 'lighted', 'tree', 'makes', 'feel', 'better']
# Cleaned: ['guess', 'isnt', 'exciting', 'story', 'really', 'meant', 'lot', 'made', 'feel', 'less', 'crappy', 'job', 'less', 'fearful', 'strangers', 'world', 'actually', 'turn', 'quite', 'nice', 'quite', 'funny']
# Cleaned: ['feel', 'respected', 'months', 'tell', 'love', 'alone', 'strikes', 'fancy']
# Cleaned: ['ive', 'decided', 'intentionally', 'make', 'easier', 'even', 'though', 'makes', 'feel', 'wimpy', 'admitting', 'reason', 'girl', 'work', 'day', 'job']
# Cleaned: ['feel', 'particularly', 'passionate', 'goals', 'changing', 'evolving', 'quickly']
# Cleaned: ['im', 'feeling', 'tortured', 'around', 'one', 'anymore']
# Cleaned: ['feel', 'lethargic', 'feel', 'blah', 'diet', 'feel', 'great', 'much', 'energy']
# Cleaned: ['feel', 'somewhat', 'frightened', 'number', 'policemen', 'arrived', 'told', 'may', 'come', 'inside', 'search', 'whatever', 'need']
# Cleaned: ['found', 'feeling', 'shaky', 'dizzy', 'exercised', 'part', 'weight', 'loss', 'could', 'due', 'getting', 'throat', 'infection']
# Cleaned: ['know', 'angry', 'every', 'right', 'feel', 'angry', 'perhaps', 'even', 'hateful', 'feelings']
# Cleaned: ['feel', 'highly', 'intelligent', 'mammals', 'destined', 'become', 'somebody', 'four', 'course', 'sake', 'accompaniment']
# Cleaned: ['feel', 'slutty', 'reason', 'oh', 'wait', 'know', 'ive', 'like', 'guys', 'talk', 'sex', 'stuff', 'one', 'guy', 'dave', 'like']
# Cleaned: ['wish', 'little', 'makes', 'feel', 'greedy', 'sheepish', 'lazy', 'worked', 'harder', 'last', 'months']
# Cleaned: ['close', 'eyes', 'moment', 'let', 'feel', 'gentle', 'warmth', 'hands', 'overlapping', 'mine', 'guiding']
# Cleaned: ['say', 'definitely', 'right', 'feel', 'furious', 'dont', 'think', 'ive', 'threatened', 'anyones', 'life', 'ever', 'anger']
# Cleaned: ['need', 'look', 'decent', 'feel', 'cute']
# Cleaned: ['squeek', 'intimate', 'scenes', 'feel', 'grossed', 'appalled', 'anyway', 'im', 'freak', 'read', 'two', 'loving', 'people', 'forget', 'theyre', 'brother', 'sister']
# Cleaned: ['feel', 'excited', 'college']
# Cleaned: ['feel', 'someone', 'wronged', 'way', 'impossible', 'sometimes', 'hard', 'get', 'past', 'without', 'apology', 'guilty', 'party']
# Cleaned: ['know', 'intellectually', 'true', 'feel', 'entirely', 'isolated']
# Cleaned: ['sacrifice', 'comfort', 'wont', 'feel', 'unwelcome']
# Cleaned: ['feel', 'like', 'mouse', 'among', 'men', 'perpetually', 'terrified']
# Cleaned: ['love', 'around', 'people', 'naturally', 'feed', 'energy', 'feel', 'alone', 'world']
# Cleaned: ['im', 'feeling', 'little', 'vain', 'today', 'outfit']
# Cleaned: ['see', 'food', 'weight', 'gain', 'feeling', 'punished', 'rather', 'need', 'control', 'times', 'know', 'pesky', 'underlying', 'issues']
# Cleaned: ['im', 'organised', 'person', 'feel', 'assured', 'pre', 'plan']
# Cleaned: ['feel', 'like', 'perfect', 'kind', 'shade', 'crazy', 'weather', 'uk', 'right', 'cloudy', 'sunny', 'windy', 'cold', 'warm']
# Cleaned: ['part', 'basically', 'feeling', 'sympathetic', 'bit', 'late', 'opinion', 'hachi', 'rushes', 'find', 'nobu', 'trying', 'help', 'nana', 'blowing', 'paper', 'bag']
# Cleaned: ['feel', 'uncertain', 'crying', 'phone', 'saying', 'cant', 'finish', 'reading']
# Cleaned: ['responded', 'feel', 'unfortunate', 'rather', 'felt', 'fortunate', 'made', 'decisions', 'could', 'sleep', 'night']
# Cleaned: ['feel', 'isolated', 'though', 'observing']
# Cleaned: ['ive', 'never', 'life', 'anyone', 'make', 'feel', 'unimportant', 'insignificant']
# Cleaned: ['feel', 'less', 'isolated']
# Cleaned: ['move', 'rooms', 'feel', 'absolutely', 'exhausted']
# Cleaned: ['always', 'think', 'past', 'start', 'crying', 'also', 'happy', 'idk', 'start', 'feeling', 'sad']
# Cleaned: ['also', 'amazing', 'community', 'friends', 'artists', 'feel', 'accepted', 'know', 'belong']
# Cleaned: ['im', 'feeling', 'gently', 'hesitant', 'posting', 'photos', 'time', 'race', 'slapped', 'copy', 'every', 'picture']
# Cleaned: ['constantly', 'tumblr', 'feel', 'free', 'follow', 'poetry', 'blog', 'riotousrambling']
# Cleaned: ['ive', 'feeling', 'sentimental', 'got', 'two', 'faux', 'diamond', 'rings']
# Cleaned: ['feel', 'write', 'something', 'making', 'reluctant']
# Cleaned: ['feel', 'fine', 'ep', 'w', 'ps', 'odeon', 'spain', 'us']
# Cleaned: ['feeling', 'generous', 'might', 'giving', 'away', 'disney', 'gift', 'card', 'blog']
# Cleaned: ['feel', 'environmentally', 'friendly', 'longer', 'produce', 'books', 'second', 'much', 'easier', 'spread', 'around', 'files', 'internet']
# Cleaned: ['feel', 'beaten', 'worked']
# Cleaned: ['im', 'feeling', 'ok', 'raging', 'hormones']
# Cleaned: ['feel', 'quite', 'honored', 'exhibit', 'work', 'portugal', 'especially', 'within', 'critical', 'philosophical', 'context', 'god', 'factor', 'project', 'said', 'west']
# Cleaned: ['miss', 'lev', 'didnt', 'think', 'would', 'cos', 'lately', 'school', 'weve', 'rubbing', 'eachother', 'bad', 'directions', 'think', 'feel', 'break', 'serving', 'splendid', 'cleansing', 'time']
# Cleaned: ['sensed', 'much', 'offer', 'also', 'many', 'many', 'times', 'behaviour', 'made', 'doubt', 'make', 'feel', 'special', 'times', 'frankly', 'rude', 'immature']
# Cleaned: ['needed', 'feeling', 'empty']
# Cleaned: ['feel', 'quite', 'idiotic', 'whatever']
# Cleaned: ['im', 'better', 'rest', 'feeling', 'feeling', 'accepted']
# Cleaned: ['still', 'feel', 'pretty', 'gloomy']
# Cleaned: ['feel', 'like', 'ungrateful', 'bitch', 'made', 'see']
# Cleaned: ['feel', 'like', 'missed', 'much', 'want', 'soak', 'every', 'thing']
# Cleaned: ['cant', 'help', 'feel', 'intelligent', 'body', 'hate', 'feeling', 'helpless', 'think', 'worked', 'really', 'isnt']
# Cleaned: ['get', 'feeling', 'totally', 'isolated', 'talk', 'low', 'self', 'esteem', 'behind', 'back', 'think', 'much', 'kind', 'killjoy', 'sometimes', 'disappointed', 'must', 'failure']
# Cleaned: ['working', 'certain', 'place', 'everyday', 'work', 'dad', 'would', 'come', 'pick', 'one', 'day', 'come']
# Cleaned: ['believe', 'readers', 'feel', 'impressed', 'individual', 'journey']
# Cleaned: ['think', 'high', 'school', 'experience', 'instantly', 'feel', 'like', 'shy', 'confused', 'terrorised', 'teenager']
# Cleaned: ['already', 'feeling', 'kind', 'frantic', 'upset', 'im', 'spending', 'another', 'year', 'god', 'forsaken', 'school']
# Cleaned: ['reply', 'best', 'reply', 'questions', 'feel', 'free', 'contact', 'via', 'twitter', 'isobelmeg', 'xx']
# Cleaned: ['feel', 'truly', 'delighted', 'already', 'changed', 'short', 'period', 'time']
# Cleaned: ['feeling', 'going', 'really', 'long', 'obnoxious']
# Cleaned: ['feel', 'energetic', 'going', 'take', 'hike']
# Cleaned: ['im', 'feeling', 'rather', 'cranky', 'impatient', 'little', 'one']
# Cleaned: ['feel', 'talented', 'precisely', 'need', 'tiger', 'tiger', 'dance', 'tiger']
# Cleaned: ['feel', 'insulted', 'victim', 'triangle']
# Cleaned: ['squirmed', 'pain', 'starting', 'get', 'stopped', 'feeling', 'resigned']
# Cleaned: ['could', 'feel', 'calf', 'muscles', 'starting', 'get', 'grouchy', 'cramp', 'around', 'ribcage']
# Cleaned: ['shouldnt', 'feel', 'altogether', 'mellow']
# Cleaned: ['feeling', 'inspired', 'get', 'work', 'done']
# Cleaned: ['know', 'solved', 'anything', 'sure', 'would', 'momentarily', 'made', 'feel', 'less', 'agitated', 'sure']
# Cleaned: ['feel', 'going', 'sequel', 'would', 'liked', 'closure', 'book', 'ending']
# Cleaned: ['feeling', 'like', 'citizen', 'feel', 'welcomed', 'japan', 'english', 'teacher', 'home', 'country', 'black', 'person']
# Cleaned: ['im', 'really', 'lucky', 'partner', 'im', 'really', 'trying', 'hard', 'keeping', 'busy', 'tasks', 'im', 'really', 'feeling', 'disheartened', 'right']
# Cleaned: ['walking', 'around', 'feeling', 'quite', 'tortured', 'spent', 'many', 'hours', 'still', 'finished', 'learned', 'things']
# Cleaned: ['understand', 'feeling', 'uncertain', 'abc', 'link']
# Cleaned: ['love', 'feel', 'blessed', 'lucky', 'able', 'travel', 'creative', 'meet', 'amazing', 'people', 'wake', 'every', 'day', 'loving', 'job']
# Cleaned: ['annoyed', 'info', 'dump', 'made', 'book', 'long', 'feel', 'miss', 'something', 'skipped', 'annoyed', 'pages']
# Cleaned: ['im', 'sure', 'parents', 'feeling', 'grandparents', 'manchester', 'ones', 'aunty', 'uncle', 'ecstatic']
# Cleaned: ['still', 'feel', 'devastated', 'disconsolate']
# Cleaned: ['feeling', 'im', 'going', 'heartless']
# Cleaned: ['feeling', 'bit', 'discouraged', 'words', 'really', 'hit', 'home']
# Cleaned: ['feel', 'sympathy', 'suffering']
# Cleaned: ['admit', 'im', 'feeling', 'pretty', 'overwhelmed']
# Cleaned: ['feel', 'would', 'loving', 'warn', 'impending', 'social', 'crises', 'facing', 'montana']
# Cleaned: ['ive', 'come', 'point', 'feel', 'submissive', 'self', 'task', 'handling']
# Cleaned: ['feel', 'happy', 'earlier']
# Cleaned: ['feeling', 'much', 'like', 'guy', 'pic', 'little', 'overwhelmed', 'starved', 'time', 'delighted', 'making', 'new', 'work', 'preparing', 'little', 'florida', 'bungalow', 'thanksgiving', 'guests', 'weekend']
# Cleaned: ['inspect', 'samples', 'wheat', 'started', 'feeling', 'suspicious', 'character']
# Cleaned: ['didnt', 'feel', 'exhausted']
# Cleaned: ['often', 'find', 'self', 'feeling', 'offended', 'hear', 'people', 'believe', 'otherwise', 'brilliant', 'people', 'following', 'consider', 'odd', 'superstitions', 'strange', 'rituals']
# Cleaned: ['remember', 'waking', 'feeling', 'anxious', 'excited', 'read', 'bible', 'amazing', 'god', 'change', 'desires']
# Cleaned: ['writer', 'block', 'feel', 'apprehensive', 'writing', 'next', 'scene', 'copy', 'paste', 'part', 'new', 'document', 'write', 'freely', 'without', 'feeling', 'set', 'stone', 'saved', 'manuscript']
# Cleaned: ['need', 'work', 'better', 'nutrition', 'time', 'feel', 'amazing']
# Cleaned: ['dont', 'even', 'know', 'going', 'write', 'wines', 'flowing', 'dining', 'rooms', 'playing', 'pandora', 'feeling', 'cosmopolitian', 'artistic', 'tonight']
# Cleaned: ['took', 'minute', 'appreciate', 'trees', 'around', 'calming', 'energy', 'gave', 'time', 'feeling', 'little', 'bit', 'irritable']
# Cleaned: ['im', 'still', 'feeling', 'wimpy', 'may', 'another', 'skip', 'around']
# Cleaned: ['im', 'feeling', 'tad', 'bit', 'gracious']
# Cleaned: ['feel', 'feel', 'fantastic']
# Cleaned: ['horrible', 'horrible', 'horrible', 'time', 'honestly', 'music', 'monkees', 'one', 'things', 'made', 'feel', 'truly', 'happy', 'right', 'tearing', 'stupid', 'yes', 'feeling', 'happy']
# Cleaned: ['feel', 'energized', 'find', 'much', 'outgoing', 'friendly']
# Cleaned: ['feel', 'pathetic', 'im', 'still', 'single']
# Cleaned: ['need', 'college', 'date', 'past', 'four', 'years', 'ive', 'always', 'felt', 'like', 'ive', 'needing', 'something', 'college', 'based', 'dont', 'still', 'feeling', 'really', 'weird', 'feel', 'almost', 'guilty', 'fact']
# Cleaned: ['feel', 'really', 'glad', 'dont', 'look', 'like', 'celebrities', 'beautiful', 'told', 'dr']
# Cleaned: ['wanted', 'perhaps', 'convey', 'feelings', 'matter', 'instead', 'thoughts', 'rejected', 'thought', 'feelings', 'matter', 'irrelevant']
# Cleaned: ['moved', 'away', 'said', 'something', 'made', 'feel', 'violent', 'something', 'still', 'cant', 'make']
# Cleaned: ['days', 'feel', 'like', 'braeden', 'calvin', 'happy', 'successful', 'day']
# Cleaned: ['feel', 'sympathetic', 'empathetic', 'towards']
# Cleaned: ['brief', 'time', 'beanbag', 'said', 'anna', 'feel', 'like', 'beaten']
# Cleaned: ['turning', 'feel', 'pathetic', 'still', 'waiting', 'tables', 'subbing', 'teaching', 'degree']
# Cleaned: ['feel', 'strong', 'good', 'overall']
# Cleaned: ['feel', 'like', 'rude', 'comment', 'im', 'glad']
# Cleaned: ['know', 'lot', 'feel', 'stupid', 'portray']

# %%
remove(df.loc[1]['text'])
# Out:
# Cleaned: ['go', 'feeling', 'hopeless', 'damned', 'hopeful', 'around', 'someone', 'cares', 'awake']
# 'go feeling hopeless damned hopeful around someone cares awake'
